# %%
pip install prophet
# Out:
# Collecting prophet
#   Using cached prophet-1.1.6-py3-none-win_amd64.whl.metadata (3.6 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Using cached cmdstanpy-1.2.4-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.15.4 in e:\anaconda\lib\site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in e:\anaconda\lib\site-packages (from prophet) (3.8.4)
# Requirement already satisfied: pandas>=1.0.4 in e:\anaconda\lib\site-packages (from prophet) (2.2.2)
# Collecting holidays<1,>=0.25 (from prophet)
#   Using cached holidays-0.58-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: tqdm>=4.36.1 in e:\anaconda\lib\site-packages (from prophet) (4.66.4)
# Collecting importlib-resources (from prophet)
#   Using cached importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Using cached stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: python-dateutil in e:\anaconda\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (23.2)
# Requirement already satisfied: pillow>=8 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas>=1.0.4->prophet) (2023.3)
# Requirement already satisfied: colorama in e:\anaconda\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil->holidays<1,>=0.25->prophet) (1.16.0)
# Using cached prophet-1.1.6-py3-none-win_amd64.whl (13.3 MB)
# Using cached cmdstanpy-1.2.4-py3-none-any.whl (94 kB)
# Using cached holidays-0.58-py3-none-any.whl (1.1 MB)
# Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Using cached stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Installing collected packages: stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.4 holidays-0.58 importlib-resources-6.4.5 prophet-1.1.6 stanio-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

data = pd.read_csv("DailyDelhiClimateTrain.csv")
print(data.head())
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
print(data.describe())
# Out:
#           meantemp     humidity   wind_speed  meanpressure
# count  1462.000000  1462.000000  1462.000000   1462.000000
# mean     25.495521    60.771702     6.802209   1011.104548
# std       7.348103    16.769652     4.561602    180.231668
# min       6.000000    13.428571     0.000000     -3.041667
# 25%      18.857143    50.375000     3.475000   1001.580357
# 50%      27.714286    62.625000     6.221667   1008.563492
# 75%      31.305804    72.218750     9.238235   1014.944901
# max      38.714286   100.000000    42.220000   7679.333333

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB
# None

# %%
figure = px.line(data, x="date", 
                 y="meantemp", 
                 title='Mean Temperature in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="humidity", 
                 title='Humidity in Delhi Over the Years')
figure.show()

# %%
figure = px.line(data, x="date", 
                 y="wind_speed", 
                 title='Wind Speed in Delhi Over the Years')
figure.show()

# %%
figure = px.scatter(data_frame = data, x="humidity",
                    y="meantemp", size="meantemp", 
                    trendline="ols", 
                    title = "Relationship Between Temperature and Humidity")
figure.show()

# %%
data["date"] = pd.to_datetime(data["date"], format = '%Y-%m-%d')
data['year'] = data['date'].dt.year
data["month"] = data["date"].dt.month
print(data.head())
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure  year  month
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667  2013      1
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000  2013      1
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667  2013      1
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667  2013      1
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000  2013      1

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.title("Temperature Change in Delhi Over the Years")
sns.lineplot(data = data, x='month', y='meantemp', hue='year')
plt.show()

# %%
forecast_data = data.rename(columns = {"date": "ds", 
                                       "meantemp": "y"})
print(forecast_data)
# Out:
#              ds          y    humidity  wind_speed  meanpressure  year  month
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667  2013      1
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000  2013      1
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667  2013      1
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667  2013      1
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000  2013      1
# ...         ...        ...         ...         ...           ...   ...    ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217  2016     12
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762  2016     12
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762  2016     12
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000  2016     12
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000  2017      1
#
# [1462 rows x 7 columns]

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
model = Prophet()
model.fit(forecast_data)
forecasts = model.make_future_dataframe(periods=365)
predictions = model.predict(forecasts)
plot_plotly(model, predictions)
# Out:
# 13:34:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:23 - cmdstanpy - INFO - Chain [1] done processing
